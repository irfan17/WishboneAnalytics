# %%
library(dplyr)
library(XML)
library(xml2)
library(tidyr)
library(stringr)
library(ggplot2)
library(maps)
library(urbnmapr)
# Out:
# Error in library(reshape): there is no package called 'reshape'
# Traceback:
#
# 1. library(reshape)

# %%
url <- "https://www.senate.gov/legislative/LIS/roll_call_lists/vote_menu_117_1.xml"

# %%
data <- read_xml(url)

# %%
dat2 <- data %>% as_list()

# %%
dat2
# Out:
# {xml_nodeset (4)}
# [1] <congress>117</congress>
# [2] <session>1</session>
# [3] <congress_year>2021</congress_year>
# [4] <votes>\n  <vote>\n    <vote_number>00528</vote_number>\n    <vote_date>1 ...

# %%
votes <- data.frame(matrix(nrow = 0, ncol = 8))
colnames(votes) <- c('issue','question','vote_date','title','vote_number','result','yeas','nays')

# %%
i = 1
while(i <= length(dat2$vote$votes)){
    if(str_trim(dat2$vote$votes[i]$vote$question) == 'On Passage of the Bill'){
    print(i)
    issue <- dat2$vote$votes[i]$vote$issue
    q <- dat2$vote$votes[i]$vote$question
    vote_date <- dat2$vote$votes[i]$vote$vote_date
    title <- dat2$vote$votes[i]$vote$title
    vote_n <- dat2$vote$votes[i]$vote$vote_number
    result <- dat2$vote$votes[i]$vote$result
    yeas <- dat2$vote$votes[i]$vote$vote_tally$yeas
    nays <- dat2$vote$votes[i]$vote$vote_tally$nays
    temp <- data.frame(issue, q, vote_date, title, vote_n, result, yeas, nays)
    colnames(temp) <- c('issue','question','vote_date','title','vote_number','result','yeas','nays')
    votes <- rbind(votes, temp)
    i = i + 1
    } else {
    i = i + 1
    }
}
# Out:
# [1] 52
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 132
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 215
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 242
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 257
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 278
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 303
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 351
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 364
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 387
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 389
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 419
# Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"Warning message in stri_trim_both(string):
# "argument is not an atomic vector; coercing"Warning message in if (str_trim(dat2$vote$votes[i]$vote$question) == "On Passage of the Bill") {:
# "the condition has length > 1 and only the first element will be used"
# [1] 525

# %%
votes
# Out:
#    issue     question                          vote_date
# 1  H.R. 6119 On Passage of the Bill\n          02-Dec
# 2  H.R. 5305 On Passage of the Bill\n          30-Sep
# 3  H.R. 3684 On Passage of the Bill\n          10-Aug
# 4  H.R. 3237 On Passage of the Bill\n          29-Jul
# 5  H.R. 1652 On Passage of the Bill\n          20-Jul
# 6  S. 1251   On Passage of the Bill\n          24-Jun
# 7  S. 1260   On Passage of the Bill\n          08-Jun
# 8  S. 914    On Passage of the Bill\n          29-Apr
# 9  S. 937    On Passage of the Bill\n          22-Apr
# 10 H.R. 1868 On Passage of the Bill\n          25-Mar
# 11 H.R. 1799 On Passage of the Bill\n          25-Mar
# 12 H.R. 1319 On Passage of the Bill\n          06-Mar
# 13 H.R. 335  On Passage of the Bill\n          21-Jan
#    title
# 1  H.R. 6119; A bill making further continuing appropriations for the fiscal year ending September 30, 2022, and for other purposes.
# 2  H.R. 5305, As Amended; A bill making continuing appropriations for the fiscal year ending September 30, 2022, and for providing emergency assistance, and for other purposes.
# 3  H.R. 3684, As Amended; A bill to authorize funds for Federal-aid highways, highway safety programs, and transit programs, and for other purposes.
# 4  H.R. 3237, As Amended; A bill making emergency supplemental appropriations for the fiscal year ending September 30, 2021, and for other purposes.
# 5  H.R. 1652; A bill to deposit certain funds into the Crime Victims Fund, to waive matching requirements, and for other purposes.
# 6  S. 1251; A bill to authorize the Secretary of Agriculture to develop a program to reduce barriers to entry for farmers, ranchers, and private forest landowners in certain voluntary markets, and for other purposes.
# 7  S. 1260, As Amended; A bill to establish a new Directorate for Technology and Innovation in the National Science Foundation, to establish a regional technology hub program, to require a strategy and report on economic security, science, research, innovation, manufacturing, and job creation, to establish a critical supply chain resiliency program, and for other purposes.
# 8  S. 914, As Amended; A bill to amend the Safe Drinking Water Act and the Federal Water Pollution Control Act to reauthorize programs under those Acts, and for other purposes.
# 9  S. 937, As Amended; A bill to facilitate the expedited review of COVID-19 hate crimes, and for other purposes.
# 10 H.R. 1868, As Amended; A bill to prevent across-the-board direct spending cuts, and for other purposes.
# 11 H.R. 1799; A bill to amend the Small Business Act and the CARES Act to extend the covered period for the paycheck protection program, and for other purposes.
# 12 H.R. 1319, As Amended; A bill to provide for reconciliation pursuant to title II of S. Con. Res. 5.
# 13 H.R. 335\n; A bill to provide for an exception to a limitation against appointment of persons as Secretary of Defense within seven years of relief from active duty as a regular commissioned officer of the Armed Forces.
#    vote_number result yeas nays
# 1  00477       Passed 69   28
# 2  00397       Passed 65   35
# 3  00314       Passed 69   30
# 4  00287       Passed 98   0
# 5  00272       Passed 100  0
# 6  00251       Passed 92   8
# 7  00226       Passed 68   32
# 8  00178       Passed 89   2
# 9  00165       Passed 94   1
# 10 00142       Passed 90   2
# 11 00140       Passed 92   7
# 12 00110       Passed 50   49
# 13 00004       Passed 69   27

# %%
vote_url <- function(congress, session, vote_number){
    url <- paste0('https://www.senate.gov/legislative/LIS/roll_call_votes/vote',congress,session,'/vote_', congress,'_',session,'_',vote_number,'.xml')
    url
}

# %%
vote_url(117,1,'00477')
# Out:
# [1] "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1171/vote_117_1_00477.xml"

# %%
url <- vote_url(117,1,'00477')
data <- read_xml(url)
dat2 <- data %>% as_list()
# Out:
# $roll_call_vote
# $roll_call_vote$congress
# $roll_call_vote$congress[[1]]
# [1] "117"
#
#
# $roll_call_vote$session
# $roll_call_vote$session[[1]]
# [1] "1"
#
#
# $roll_call_vote$congress_year
# $roll_call_vote$congress_year[[1]]
# [1] "2021"
#
#
# $roll_call_vote$vote_number
# $roll_call_vote$vote_number[[1]]
# [1] "477"
#
#
# $roll_call_vote$vote_date
# $roll_call_vote$vote_date[[1]]
# [1] "December 2, 2021,  09:05 PM"
#
#
# $roll_call_vote$modify_date
# $roll_call_vote$modify_date[[1]]
# [1] "December 2, 2021,  09:34 PM"
#
#
# $roll_call_vote$vote_question_text
# $roll_call_vote$vote_question_text[[1]]
# [1] "On Passage of the Bill H.R. 6119"
#
#
# $roll_call_vote$vote_document_text
# list()
#
# $roll_call_vote$vote_result_text
# $roll_call_vote$vote_result_text[[1]]
# [1] "Bill Passed (69-28, 3/5 majority required)"
#
#
# $roll_call_vote$question
# $roll_call_vote$question[[1]]
# [1] "On Passage of the Bill"
#
#
# $roll_call_vote$vote_title
# $roll_call_vote$vote_title[[1]]
# [1] "H.R. 6119"
#
#
# $roll_call_vote$majority_requirement
# $roll_call_vote$majority_requirement[[1]]
# [1] "3/5"
#
#
# $roll_call_vote$vote_result
# $roll_call_vote$vote_result[[1]]
# [1] "Bill Passed"
#
#
# $roll_call_vote$document
# $roll_call_vote$document$document_congress
# $roll_call_vote$document$document_congress[[1]]
# [1] "117"
#
#
# $roll_call_vote$document$document_type
# $roll_call_vote$document$document_type[[1]]
# [1] "H.R."
#
#
# $roll_call_vote$document$document_number
# $roll_call_vote$document$document_number[[1]]
# [1] "6119"
#
#
# $roll_call_vote$document$document_name
# $roll_call_vote$document$document_name[[1]]
# [1] "H.R. 6119"
#
#
# $roll_call_vote$document$document_title
# list()
#
# $roll_call_vote$document$document_short_title
# list()
#
#
# $roll_call_vote$amendment
# $roll_call_vote$amendment$amendment_number
# list()
#
# $roll_call_vote$amendment$amendment_to_amendment_number
# list()
#
# $roll_call_vote$amendment$amendment_to_amendment_to_amendment_number
# list()
#
# $roll_call_vote$amendment$amendment_to_document_number
# list()
#
# $roll_call_vote$amendment$amendment_to_document_short_title
# list()
#
# $roll_call_vote$amendment$amendment_purpose
# $roll_call_vote$amendment$amendment_purpose[[1]]
# [1] "No Statement of Purpose on File."
#
#
#
# $roll_call_vote$count
# $roll_call_vote$count$yeas
# $roll_call_vote$count$yeas[[1]]
# [1] "69"
#
#
# $roll_call_vote$count$nays
# $roll_call_vote$count$nays[[1]]
# [1] "28"
#
#
# $roll_call_vote$count$present
# list()
#
# $roll_call_vote$count$absent
# $roll_call_vote$count$absent[[1]]
# [1] "3"
#
#
#
# $roll_call_vote$tie_breaker
# $roll_call_vote$tie_breaker$by_whom
# list()
#
# $roll_call_vote$tie_breaker$tie_breaker_vote
# list()
#
#
# $roll_call_vote$members
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Baldwin (D-WI)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Baldwin"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tammy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WI"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S354"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Barrasso (R-WY)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Barrasso"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WY"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S317"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Bennet (D-CO)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Bennet"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Michael"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "CO"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S330"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Blackburn (R-TN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Blackburn"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Marsha"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "TN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S396"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Blumenthal (D-CT)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Blumenthal"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Richard"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "CT"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S341"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Blunt (R-MO)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Blunt"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Roy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MO"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S342"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Booker (D-NJ)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Booker"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Cory"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NJ"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S370"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Boozman (R-AR)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Boozman"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AR"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S343"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Braun (R-IN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Braun"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mike"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S397"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Brown (D-OH)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Brown"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Sherrod "
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "OH"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S307"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Burr (R-NC)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Burr"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Richard"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NC"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S300"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cantwell (D-WA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cantwell"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Maria"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S275"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Capito (R-WV)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Capito"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Shelley"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WV"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S372"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cardin (D-MD)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cardin"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Ben"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MD"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S308"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Carper (D-DE)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Carper"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Thomas"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "DE"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S277"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Casey (D-PA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Casey"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Bob"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "PA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S309"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cassidy (R-LA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cassidy"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Bill"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "LA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S373"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Collins (R-ME)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Collins"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Susan"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "ME"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S252"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Coons (D-DE)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Coons"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Christopher"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "DE"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S337"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cornyn (R-TX)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cornyn"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "TX"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S287"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cortez Masto (D-NV)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cortez Masto"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Catherine"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NV"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S385"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cotton (R-AR)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cotton"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tom"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AR"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S374"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cramer (R-ND)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cramer"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Kevin"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "ND"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S398"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Crapo (R-ID)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Crapo"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mike"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "ID"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S266"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Cruz (R-TX)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Cruz"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Ted"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "TX"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S355"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Daines (R-MT)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Daines"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Steve"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MT"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S375"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Duckworth (D-IL)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Duckworth"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tammy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IL"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S386"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Durbin (D-IL)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Durbin"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Richard"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IL"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S253"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Ernst (R-IA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Ernst"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Joni"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S376"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Feinstein (D-CA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Feinstein"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Dianne"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "CA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S221"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Fischer (R-NE)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Fischer"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Deb"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NE"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S357"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Gillibrand (D-NY)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Gillibrand"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Kirsten"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NY"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S331"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Graham (R-SC)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Graham"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Lindsey"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "SC"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S293"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Grassley (R-IA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Grassley"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Charles"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S153"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hagerty (R-TN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hagerty"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Bill"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "TN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Not Voting"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S407"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hassan (D-NH)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hassan"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Maggie"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NH"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S388"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hawley (R-MO)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hawley"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Josh"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MO"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S399"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Heinrich (D-NM)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Heinrich"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Martin"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NM"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S359"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hickenlooper (D-CO)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hickenlooper"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "CO"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S408"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hirono (D-HI)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hirono"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mazie"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "HI"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S361"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hoeven (R-ND)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hoeven"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "ND"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S344"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Hyde-Smith (R-MS)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Hyde-Smith"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Cindy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MS"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S395"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Inhofe (R-OK)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Inhofe"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Jim"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "OK"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Not Voting"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S236"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Johnson (R-WI)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Johnson"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Ron"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WI"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S345"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Kaine (D-VA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Kaine"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Timothy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "VA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S362"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Kelly (D-AZ)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Kelly"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mark"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AZ"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S406"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Kennedy (R-LA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Kennedy"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "LA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S389"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "King (I-ME)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "King"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Angus"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "I"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "ME"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S363"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Klobuchar (D-MN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Klobuchar"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Amy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S311"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Lankford (R-OK)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Lankford"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "James"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "OK"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S378"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Leahy (D-VT)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Leahy"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Patrick"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "VT"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S057"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Lee (R-UT)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Lee"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mike"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "UT"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S346"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Lujan (D-NM)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Lujan"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Ben"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NM"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S409"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Lummis (R-WY)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Lummis"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Cynthia"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WY"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S410"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Manchin (D-WV)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Manchin"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Joseph"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "WV"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S338"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Markey (D-MA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Markey"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Edward"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S369"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Marshall (R-KS)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Marshall"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Roger"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "KS"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S411"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "McConnell (R-KY)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "McConnell"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mitch"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "KY"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S174"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Menendez (D-NJ)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Menendez"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Robert"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NJ"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S306"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Merkley (D-OR)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Merkley"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Jeff"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "OR"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S322"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Moran (R-KS)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Moran"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Jerry"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "KS"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S347"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Murkowski (R-AK)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Murkowski"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Lisa"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# ...
# [1] "Schumer"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Charles"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NY"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S270"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Scott (R-FL)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Scott"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Rick"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "FL"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S404"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Scott (R-SC)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Scott"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tim"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "SC"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S365"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Shaheen (D-NH)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Shaheen"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Jeanne"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NH"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S324"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Shelby (R-AL)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Shelby"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Richard"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AL"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S184"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Sinema (D-AZ)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Sinema"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Kyrsten"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AZ"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S403"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Smith (D-MN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Smith"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tina"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S394"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Stabenow (D-MI)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Stabenow"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Debbie"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MI"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S284"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Sullivan (R-AK)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Sullivan"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Dan"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AK"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S383"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Tester (D-MT)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Tester"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Jon"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MT"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S314"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Thune (R-SD)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Thune"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "John"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "SD"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Not Voting"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S303"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Tillis (R-NC)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Tillis"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Thomas"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "NC"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S384"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Toomey (R-PA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Toomey"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Patrick"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "PA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S351"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Tuberville (R-AL)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Tuberville"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Tommy"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "AL"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Nay"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S412"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Van Hollen (D-MD)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Van Hollen"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Chris"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MD"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S390"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Warner (D-VA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Warner"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Mark"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "VA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S327"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Warnock (D-GA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Warnock"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Raphael"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "GA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S415"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Warren (D-MA)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Warren"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Elizabeth"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MA"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S366"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Whitehouse (D-RI)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Whitehouse"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Sheldon"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "RI"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S316"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Wicker (R-MS)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Wicker"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Roger"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "MS"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S318"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Wyden (D-OR)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Wyden"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Ron"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "D"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "OR"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S247"
#
#
#
# $roll_call_vote$members$member
# $roll_call_vote$members$member$member_full
# $roll_call_vote$members$member$member_full[[1]]
# [1] "Young (R-IN)"
#
#
# $roll_call_vote$members$member$last_name
# $roll_call_vote$members$member$last_name[[1]]
# [1] "Young"
#
#
# $roll_call_vote$members$member$first_name
# $roll_call_vote$members$member$first_name[[1]]
# [1] "Todd"
#
#
# $roll_call_vote$members$member$party
# $roll_call_vote$members$member$party[[1]]
# [1] "R"
#
#
# $roll_call_vote$members$member$state
# $roll_call_vote$members$member$state[[1]]
# [1] "IN"
#
#
# $roll_call_vote$members$member$vote_cast
# $roll_call_vote$members$member$vote_cast[[1]]
# [1] "Yea"
#
#
# $roll_call_vote$members$member$lis_member_id
# $roll_call_vote$members$member$lis_member_id[[1]]
# [1] "S391"

# %%
dat2$roll_call_vote$members %>% length()
# Out:
# [1] 100

# %%
test <- dat2$roll_call_vote$members[2]$member %>% as.data.frame()
colnames(test) <- dat2$roll_call_vote$members[2]$member %>% names()
test
# Out:
#   member_full     last_name first_name party state vote_cast lis_member_id
# 1 Barrasso (R-WY) Barrasso  John       R     WY    Nay       S317

# %%
memb <- data.frame(matrix(nrow = 0, ncol = 7))
colnames(memb) <- c('Member','Last','First','Party','State','Vote','Member_ID')
i = 1
while(i <= length(dat2$roll_call_vote$members)){
    temp <- dat2$roll_call_vote$members[i]$member %>% as.data.frame()
    colnames(temp) <- c('Member','Last','First','Party','State','Vote','Member_ID')
    memb <- rbind(memb, temp)
    i = i + 1
}

# %%
memb
# Out:
#     Member              Last         First       Party State Vote
# 1   Baldwin (D-WI)      Baldwin      Tammy       D     WI    Yea
# 2   Barrasso (R-WY)     Barrasso     John        R     WY    Nay
# 3   Bennet (D-CO)       Bennet       Michael     D     CO    Yea
# 4   Blackburn (R-TN)    Blackburn    Marsha      R     TN    Nay
# 5   Blumenthal (D-CT)   Blumenthal   Richard     D     CT    Yea
# 6   Blunt (R-MO)        Blunt        Roy         R     MO    Yea
# 7   Booker (D-NJ)       Booker       Cory        D     NJ    Yea
# 8   Boozman (R-AR)      Boozman      John        R     AR    Nay
# 9   Braun (R-IN)        Braun        Mike        R     IN    Nay
# 10  Brown (D-OH)        Brown        Sherrod     D     OH    Yea
# 11  Burr (R-NC)         Burr         Richard     R     NC    Yea
# 12  Cantwell (D-WA)     Cantwell     Maria       D     WA    Yea
# 13  Capito (R-WV)       Capito       Shelley     R     WV    Yea
# 14  Cardin (D-MD)       Cardin       Ben         D     MD    Yea
# 15  Carper (D-DE)       Carper       Thomas      D     DE    Yea
# 16  Casey (D-PA)        Casey        Bob         D     PA    Yea
# 17  Cassidy (R-LA)      Cassidy      Bill        R     LA    Yea
# 18  Collins (R-ME)      Collins      Susan       R     ME    Yea
# 19  Coons (D-DE)        Coons        Christopher D     DE    Yea
# 20  Cornyn (R-TX)       Cornyn       John        R     TX    Yea
# 21  Cortez Masto (D-NV) Cortez Masto Catherine   D     NV    Yea
# 22  Cotton (R-AR)       Cotton       Tom         R     AR    Nay
# 23  Cramer (R-ND)       Cramer       Kevin       R     ND    Nay
# 24  Crapo (R-ID)        Crapo        Mike        R     ID    Nay
# 25  Cruz (R-TX)         Cruz         Ted         R     TX    Nay
# 26  Daines (R-MT)       Daines       Steve       R     MT    Nay
# 27  Duckworth (D-IL)    Duckworth    Tammy       D     IL    Yea
# 28  Durbin (D-IL)       Durbin       Richard     D     IL    Yea
# 29  Ernst (R-IA)        Ernst        Joni        R     IA    Nay
# 30  Feinstein (D-CA)    Feinstein    Dianne      D     CA    Yea
# ... ...                 ...          ...         ...   ...   ...
# 71  Risch (R-ID)        Risch        James       R     ID    Nay
# 72  Romney (R-UT)       Romney       Mitt        R     UT    Nay
# 73  Rosen (D-NV)        Rosen        Jacklyn     D     NV    Yea
# 74  Rounds (R-SD)       Rounds       Mike        R     SD    Yea
# 75  Rubio (R-FL)        Rubio        Marco       R     FL    Yea
# 76  Sanders (I-VT)      Sanders      Bernard     I     VT    Yea
# 77  Sasse (R-NE)        Sasse        Ben         R     NE    Nay
# 78  Schatz (D-HI)       Schatz       Brian       D     HI    Yea
# 79  Schumer (D-NY)      Schumer      Charles     D     NY    Yea
# 80  Scott (R-FL)        Scott        Rick        R     FL    Nay
# 81  Scott (R-SC)        Scott        Tim         R     SC    Nay
# 82  Shaheen (D-NH)      Shaheen      Jeanne      D     NH    Yea
# 83  Shelby (R-AL)       Shelby       Richard     R     AL    Yea
# 84  Sinema (D-AZ)       Sinema       Kyrsten     D     AZ    Yea
# 85  Smith (D-MN)        Smith        Tina        D     MN    Yea
# 86  Stabenow (D-MI)     Stabenow     Debbie      D     MI    Yea
# 87  Sullivan (R-AK)     Sullivan     Dan         R     AK    Nay
# 88  Tester (D-MT)       Tester       Jon         D     MT    Yea
# 89  Thune (R-SD)        Thune        John        R     SD    Not Voting
# 90  Tillis (R-NC)       Tillis       Thomas      R     NC    Yea
# 91  Toomey (R-PA)       Toomey       Patrick     R     PA    Nay
# 92  Tuberville (R-AL)   Tuberville   Tommy       R     AL    Nay
# 93  Van Hollen (D-MD)   Van Hollen   Chris       D     MD    Yea
# 94  Warner (D-VA)       Warner       Mark        D     VA    Yea
# 95  Warnock (D-GA)      Warnock      Raphael     D     GA    Yea
# 96  Warren (D-MA)       Warren       Elizabeth   D     MA    Yea
# 97  Whitehouse (D-RI)   Whitehouse   Sheldon     D     RI    Yea
# 98  Wicker (R-MS)       Wicker       Roger       R     MS    Yea
# 99  Wyden (D-OR)        Wyden        Ron         D     OR    Yea
# 100 Young (R-IN)        Young        Todd        R     IN    Yea
#     Member_ID
# 1   S354
# 2   S317
# 3   S330
# 4   S396
# 5   S341
# 6   S342
# 7   S370
# 8   S343
# 9   S397
# 10  S307
# 11  S300
# 12  S275
# 13  S372
# 14  S308
# 15  S277
# 16  S309
# 17  S373
# 18  S252
# 19  S337
# 20  S287
# 21  S385
# 22  S374
# 23  S398
# 24  S266
# 25  S355
# 26  S375
# 27  S386
# 28  S253
# 29  S376
# 30  S221
# ... ...
# 71  S323
# 72  S401
# 73  S402
# 74  S381
# 75  S350
# 76  S313
# 77  S382
# 78  S353
# 79  S270
# 80  S404
# 81  S365
# 82  S324
# 83  S184
# 84  S403
# 85  S394
# 86  S284
# 87  S383
# 88  S314
# 89  S303
# 90  S384
# 91  S351
# 92  S412
# 93  S390
# 94  S327
# 95  S415
# 96  S366
# 97  S316
# 98  S318
# 99  S247
# 100 S391

# %%
test <- memb %>% select(c(State, Party, Vote)) %>% count(State,Party) %>% select(State, Party, n) %>% group_by(State)

# %%
test2 <- memb %>% select(c(State, Party, Vote)) %>% count(State,Party,Vote) %>% select(State, Party,Vote, n) %>% group_by(State)

# %%
states <- test2 %>% select(State) %>% unique()
states$col <- ''
states$party_col <- ''

# %%
ifelse(test %>% filter(State == 'WA') %>% filter(Party == 'D') %>% nrow() == 0,0, test %>% filter(State == 'WA') %>% filter(Party == 'D') %>% pull(n))
# Out:
# [1] 2

# %%
i =1
while(i <= nrow(states)){
    temp <- test2[test2$State == states$State[i],]
    #temp_party <- test[test$State == states$State[i],]
    temp2 <- data.frame(cbind(c("Y","N"),0))
    colnames(temp2) <- c("vote","count")
    party <- data.frame(cbind(c("D","R"),0))
    colnames(party) <- c("party","count")
    temp2$count <- as.numeric(temp2$count)
    party$count <- as.numeric(party$count)
    temp2$count[1] <- ifelse(length(temp$n[temp$Vote == 'Yea']) > 0, as.numeric(temp$n[temp$Vote == 'Yea']), 0)
    temp2$count[2] <- ifelse(length(temp$n[temp$Vote == 'Nay']) > 0, as.numeric(temp$n[temp$Vote == 'Nay']), 0)
    party$count[1] <- ifelse(test %>% filter(State == states$State[i]) %>% filter(Party == 'D') %>% nrow() == 0,0, test %>% filter(State == states$State[i]) %>% filter(Party == 'D') %>% pull(n))
    party$count[2] <- ifelse(test %>% filter(State == states$State[i]) %>% filter(Party == 'R') %>% nrow() == 0,0, test %>% filter(State == states$State[i]) %>% filter(Party == 'R') %>% pull(n))
    #print(temp2)
    states$col[i] <- ifelse( temp2$count[temp2$vote == 'Y'] == 2, "Green",
                           ifelse(temp2$count[temp2$vote == 'N'] == 2, "Brown1","Yellow"))
    states$party_col[i] <- ifelse(party$count[party$party == 'D'] == 2, "CornflowerBlue",
                           ifelse(temp$State == 'VT', "CornflowerBlue",
                           ifelse(party$count[party$party == 'R'] == 2, "Brown1","DarkViolet")))
    #print(states)
    i = i + 1
}
print(states)
# Out:
# Warning message:
# "`...` is not empty.
#
# We detected these problematic arguments:
# * `needs_dots`
#
# These dots only exist to allow future extensions and should be empty.
# Did you misspecify an argument?"
# # A tibble: 50 x 3
# # Groups:   State [50]
#    State col    party_col
#    <fct> <chr>  <chr>
#  1 WI    Yellow DarkViolet
#  2 WY    Brown1 Brown1
#  3 CO    Green  CornflowerBlue
#  4 TN    Yellow Brown1
#  5 CT    Green  CornflowerBlue
#  6 MO    Yellow Brown1
#  7 NJ    Green  CornflowerBlue
#  8 AR    Brown1 Brown1
#  9 IN    Yellow Brown1
# 10 OH    Yellow DarkViolet
# # ... with 40 more rows

# %%
comb <- as.data.frame(left_join(states, urbnmapr::states, by = c("State" = "state_abbv")))

# %%
ggplot() + 
  geom_polygon(data = comb, mapping = aes(x = long, y = lat, group = group),
		           fill = comb$party_col, color = "black") +
  coord_map(projection = "albers", lat0 = 39, lat1 = 45) + theme_void() + ggtitle("117th Senate Delegations")
# Out:
# plot without title

# %%
head(comb)
# Out:
#   State col    long      lat      order hole  piece group state_fips state_name
# 1 WI    Purple -92.88811 45.62838 81153 FALSE 1     55.1  55         Wisconsin
# 2 WI    Purple -92.88683 45.63340 81154 FALSE 1     55.1  55         Wisconsin
# 3 WI    Purple -92.88696 45.63678 81155 FALSE 1     55.1  55         Wisconsin
# 4 WI    Purple -92.88793 45.63901 81156 FALSE 1     55.1  55         Wisconsin
# 5 WI    Purple -92.88707 45.64415 81157 FALSE 1     55.1  55         Wisconsin
# 6 WI    Purple -92.88571 45.64602 81158 FALSE 1     55.1  55         Wisconsin
